# %%
from pydantic_ai import Agent
from pydantic_ai.models.openai import OpenAIResponsesModel, OpenAIResponsesModelSettings

# %%
from time import time

# %%
instructions = """
You're a research agent, your task is to find articles on the internet and 
answer the question from the user. Make sure you include references in the 
answer you generate
"""

user_prompt = "How do I do RAG in 2026?"

model = OpenAIResponsesModel('gpt-4o-mini')

model_settings = OpenAIResponsesModelSettings(
    openai_builtin_tools=[
        {"type": "web_search"}
    ],
    openai_include_web_search_sources=True,
    openai_include_raw_annotations=True,
)

search_agent = Agent(
    name='search',
    model=model,
    instructions=instructions,
    model_settings=model_settings
)

# %%
start = time()

result = await search_agent.run(user_prompt)

end = time()

print(f'took {end - start} seconds')
# Out:
# took 5.210209369659424 seconds

# %%
print(result.output)
# Out:
# Retrieval-Augmented Generation (RAG) has evolved significantly by 2026, becoming a cornerstone in developing advanced AI systems. To implement RAG effectively in 2026, consider the following steps:
#
# 1. **Data Ingestion and Preparation**: Utilize deep document understanding (DDU) techniques to process diverse data types, including PDFs, scanned documents, and structured records. This ensures data is cleansed, de-duplicated, and semantically segmented, preserving context and relationships. ([linkedin.com](https://www.linkedin.com/pulse/strategic-evolution-retrieval-augmented-generation-s83cc?utm_source=openai))
#
# 2. **Semantic Chunking and Embedding**: Divide documents into semantically meaningful units, typically around 1,000 tokens with 200-token overlaps, to maintain context continuity. Convert these chunks into high-dimensional embeddings using models like BERT or GPT, capturing semantic similarities beyond mere keyword matching. ([linkedin.com](https://www.linkedin.com/pulse/strategic-evolution-retrieval-augmented-generation-s83cc?utm_source=openai))
#
# 3. **Efficient Retrieval Mechanisms**: Store embeddings in vector databases optimized for rapid retrieval, employing structures like HNSW graphs and techniques such as horizontal sharding and replication for fault tolerance. ([linkedin.com](https://www.linkedin.com/pulse/strategic-evolution-retrieval-augmented-generation-s83cc?utm_source=openai))
#
# 4. **Hybrid Retrieval and Re-Ranking**: Combine semantic search with traditional keyword-based methods (e.g., BM25) to enhance retrieval robustness. Implement cross-encoder re-rankers to refine the relevance of retrieved documents, ensuring only the most pertinent information is passed to the generative model. ([linkedin.com](https://www.linkedin.com/pulse/strategic-evolution-retrieval-augmented-generation-s83cc?utm_source=openai))
#
# 5. **Prompt Engineering and Guardrails**: Design prompts that integrate retrieved information, enforcing source grounding and enabling the model to handle cases where data is missing. This approach supports citations and auditability, crucial for compliance and transparency. ([linkedin.com](https://www.linkedin.com/pulse/strategic-evolution-retrieval-augmented-generation-s83cc?utm_source=openai))
#
# 6. **Generation with Source Attribution**: Ensure the generative model produces responses with clear references to source documents, enhancing trust and verifiability. This is particularly important in regulated industries where explainability is mandatory. ([linkedin.com](https://www.linkedin.com/pulse/strategic-evolution-retrieval-augmented-generation-s83cc?utm_source=openai))
#
# By following these steps, you can build a robust RAG system that leverages the latest advancements in AI to deliver accurate, contextually relevant, and trustworthy outputs.

# %%
req, resp = result.new_messages()

# %%
tcp, tcr, text = resp.parts

# %%
tcp.args
# Out:
# {'query': 'RAG 2026 retrieval augmented generation methods and best practices',
#  'type': 'search',
#  'queries': ['RAG 2026 retrieval augmented generation methods and best practices']}

# %%
tcr.content['sources']
# Out:
# [{'type': 'url',
#   'url': 'https://www.aclweb.org/portal/content/1st-workshop-retrieval-augmented-generation-report-generation-acl-2026?utm_source=openai'},
#  {'type': 'url',
#   'url': 'https://ace.ewapub.com/article/view/24496?utm_source=openai'},
#  {'type': 'url',
#   'url': 'https://qconlondon.com/topic/retrieval-augmented-generation?utm_source=openai'},
#  {'type': 'url',
#   'url': 'https://www.linkedin.com/pulse/strategic-evolution-retrieval-augmented-generation-s83cc?utm_source=openai'},
#  {'type': 'url',
#   'url': 'https://www.linkedin.com/pulse/complete-2026-guide-modern-rag-architectures-how-retrieval-pathan-rx1nf?utm_source=openai'},
#  {'type': 'url',
#   'url': 'https://verysell.ai/retrieval-augmented-generation-best-knowledge-for-2026/?utm_source=openai'},
#  {'type': 'url',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S0306457325003905?utm_source=openai'},
#  {'type': 'url',
#   'url': 'https://www.programming-helper.com/tech/rag-2026-retrieval-augmented-generation-enterprise-genai-python?utm_source=openai'},
#  {'type': 'url',
#   'url': 'https://aclanthology.org/2025.findings-emnlp.321/?utm_source=openai'},
#  {'type': 'url',
#   'url': 'https://www.emergentmind.com/topics/retrieval-augmented-generation-rag-algorithms?utm_source=openai'},
#  {'type': 'url',
#   'url': 'https://medium.com/%40surajkhaitan16/rag-in-2026-a-practical-blueprint-for-retrieval-augmented-generation-f29f37298461?utm_source=openai'},
#  {'type': 'url',
#   'url': 'https://www.rankwit.ai/blog/retrieval-augmented-generation-rag-2025?utm_source=openai'}]

# %%
text.provider_details['annotations']
# Out:
# [{'end_index': 616,
#   'start_index': 493,
#   'title': 'The Strategic Evolution of Retrieval-Augmented Generation (RAG) in 2026',
#   'type': 'url_citation',
#   'url': 'https://www.linkedin.com/pulse/strategic-evolution-retrieval-augmented-generation-s83cc?utm_source=openai'},
#  {'end_index': 1068,
#   'start_index': 945,
#   'title': 'The Strategic Evolution of Retrieval-Augmented Generation (RAG) in 2026',
#   'type': 'url_citation',
#   'url': 'https://www.linkedin.com/pulse/strategic-evolution-retrieval-augmented-generation-s83cc?utm_source=openai'},
#  {'end_index': 1418,
#   'start_index': 1295,
#   'title': 'The Strategic Evolution of Retrieval-Augmented Generation (RAG) in 2026',
#   'type': 'url_citation',
#   'url': 'https://www.linkedin.com/pulse/strategic-evolution-retrieval-augmented-generation-s83cc?utm_source=openai'},
#  {'end_index': 1855,
#   'start_index': 1732,
#   'title': 'The Strategic Evolution of Retrieval-Augmented Generation (RAG) in 2026',
#   'type': 'url_citation',
#   'url': 'https://www.linkedin.com/pulse/strategic-evolution-retrieval-augmented-generation-s83cc?utm_source=openai'},
#  {'end_index': 2256,
#   'start_index': 2133,
#   'title': 'The Strategic Evolution of Retrieval-Augmented Generation (RAG) in 2026',
#   'type': 'url_citation',
#   'url': 'https://www.linkedin.com/pulse/strategic-evolution-retrieval-augmented-generation-s83cc?utm_source=openai'},
#  {'end_index': 2639,
#   'start_index': 2516,
#   'title': 'The Strategic Evolution of Retrieval-Augmented Generation (RAG) in 2026',
#   'type': 'url_citation',
#   'url': 'https://www.linkedin.com/pulse/strategic-evolution-retrieval-augmented-generation-s83cc?utm_source=openai'}]
