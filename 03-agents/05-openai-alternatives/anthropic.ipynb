# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

import common
from search_tools import create_search_tools

evidently_search_tools = create_search_tools()

# %%
import inspect

search_tool = {
    "name": evidently_search_tools.search.__name__,
    "description": inspect.getdoc(evidently_search_tools.search),
    "input_schema": {
        "type": "object",
        "properties": {
            "query": {
                "type": "string",
                "description": "query parameter"
            }
        },
        "required": [
            "query"
        ]
    }
}

get_file_tool = {
    "name": evidently_search_tools.get_file.__name__,
    "description": inspect.getdoc(evidently_search_tools.get_file),
    "input_schema": {
        "type": "object",
        "properties": {
            "filename": {
                "type": "string",
                "description": "filename parameter"
            }
        },
        "required": [
            "filename"
        ]
    }
}

# %%
tool_pairs = [
    (evidently_search_tools.search, search_tool),
    (evidently_search_tools.get_file, get_file_tool)
]

# %%
tools = [t for (_, t) in tool_pairs]
tools_index = {t["name"]: f for (f, t) in tool_pairs}

# %%
def make_call(tool_call):
    name = tool_call.name

    if name in tools_index:
        func = tools_index[name]
        arguments = tool_call.input
        result = func(**arguments)
    else:
        result = f"Tool '{name}' not found in tools index"

    return {
        "type": "tool_result",
        "tool_use_id": tool_call.id,
        "content": json.dumps(result)
    }

# %%
from dataclasses import dataclass

@dataclass
class ToolCall:
    id: str
    name: str
    input: str

tool_call = ToolCall(name="search", input={"query": "dashboard"}, id="1234")
tool_call_result = make_call(tool_call)
tool_call_result
# Out:
# {'type': 'tool_result',
#  'tool_use_id': '1234',
#  'content': '[{"title": "Add dashboard panels (UI)", "description": "How to design your Dashboard with custom Panels.", "content": {"matches": ["**Dashboards** let you create Panels to...", "...ject.\\n\\n<Check>\\n  No-code **Dashboards** are available in the Evi...", "...anels appear on a single **Dashboard**. You can add multiple Ta..."], "total_matches": 11}, "filename": "docs/platform/dashboard_add_panels_ui.mdx"}, {"title": "Add dashboard panels (API)", "description": "How to design your Dashboard with custom Panels.", "content": {"matches": ["...oard_add_panels_ui).\\n\\n## **Dashboard** Management\\n\\n<Check>\\n  **Dashboards**...", "...rd Management\\n\\n<Check>\\n  **Dashboards** as code are available in...", "... Tab:\\n\\n```python\\nproject.**dashboard**.add_tab(\\"Another Tab\\")\\n`..."], "total_matches": 27}, "filename": "docs/platform/dashboard_add_panels.mdx"}, {"title": "Dashboard panel types [Legacy]", "description": "Overview of the available monitoring Panels.", "content": {"matches": ["...ounter on the Monitoring **Dashboard**.\\u00a0\\n\\n* You can add multipl...", "...es in time.\\n\\n![](/images/**dashboard**/metric_panels.png)\\n\\n**Pa...", "... text alone. Perfect for **dashboard** titles.\\n\\n<Frame>\\n  <img ..."], "total_matches": 62}, "filename": "docs/platform/dashboard_panel_types.mdx"}, {"title": "Overview", "description": "Introduction to Dashboard.", "content": {"matches": ["<Check>\\n  **Dashboard** is available in **Eviden...", "....\\n</Check>\\n\\n## What is a **Dashboard**?\\n\\nA **Dashboard** provides a...", "... What is a **Dashboard**?\\n\\nA **Dashboard** provides a clear view of..."], "total_matches": 17}, "filename": "docs/platform/dashboard_overview.mdx"}, {"title": "Data definition", "description": "How to map the input data.", "content": {"matches": ["...hen you plot them on the **dashboard**.\\n\\nHowever, if you comput..."], "total_matches": 1}, "filename": "docs/library/data_definition.mdx"}]'}

# %%
from anthropic import Anthropic
anthropic_client = Anthropic()

# %%
messages = [
    {"role": "user", "content": common.DEFAULT_QUESTION}
]

# 1st call - initial

response = anthropic_client.messages.create(
    model="claude-haiku-4-5",
    max_tokens=4096,
    system=common.SINGLE_TOOL_SYSTEM_PROMPT,
    messages=messages,
    tools=tools,
)

# %%
response.content
# Out:
# [ToolUseBlock(id='toolu_01FMJcDzHPYnSkDGhqF8KnvH', input={'query': 'create dashboard'}, name='search', type='tool_use', caller={'type': 'direct'})]

# %%
tool_call = [m for m in response.content if m.type == 'tool_use'][0]
tool_call
# Out:
# ToolUseBlock(id='toolu_01FMJcDzHPYnSkDGhqF8KnvH', input={'query': 'create dashboard'}, name='search', type='tool_use', caller={'type': 'direct'})

# %%
print(f"Tool call: {tool_call.name}({tool_call.input})")
# Out:
# Tool call: search({'query': 'create dashboard'})

# %%
tool_call_result = make_call(tool_call)
tool_call_result
# Out:
# {'type': 'tool_result',
#  'tool_use_id': 'toolu_01FMJcDzHPYnSkDGhqF8KnvH',
#  'content': '[{"title": "Add dashboard panels (UI)", "description": "How to design your Dashboard with custom Panels.", "content": {"matches": ["**Dashboards** let you **create** Panels to...", "**Dashboards** let you **create** Panels to visualize eval...", "...ject.\\n\\n<Check>\\n  No-code **Dashboards** are available in the Evi..."], "total_matches": 14}, "filename": "docs/platform/dashboard_add_panels_ui.mdx"}, {"title": "Add dashboard panels (API)", "description": "How to design your Dashboard with custom Panels.", "content": {"matches": ["...oard_add_panels_ui).\\n\\n## **Dashboard** Management\\n\\n<Check>\\n  **Dashboards**...", "...rd Management\\n\\n<Check>\\n  **Dashboards** as code are available in...", "...(/docs/setup/cloud) and [**create** a Project](/docs/platfor..."], "total_matches": 32}, "filename": "docs/platform/dashboard_add_panels.mdx"}, {"title": "Custom Metric", "description": "How to create a custom dataset or column-level Metric.", "content": {"matches": ["...e a built-in template to **create** a custom [LLM-based eval...", "...sualize over time on the **Dashboard**.\\n\\n## Example implementat...", "... Report as usual.\\n\\nLet\\u2019s **create** a sample toy dataset:\\n\\n`..."], "total_matches": 3}, "filename": "metrics/customize_metric.mdx"}, {"title": "Dashboard panel types [Legacy]", "description": "Overview of the available monitoring Panels.", "content": {"matches": ["...ounter on the Monitoring **Dashboard**.\\u00a0\\n\\n* You can add multipl...", "...es in time.\\n\\n![](/images/**dashboard**/metric_panels.png)\\n\\n**Pa...", "... text alone. Perfect for **dashboard** titles.\\n\\n<Frame>\\n  <img ..."], "total_matches": 68}, "filename": "docs/platform/dashboard_panel_types.mdx"}, {"title": "Overview", "description": "Introduction to Dashboard.", "content": {"matches": ["<Check>\\n  **Dashboard** is available in **Eviden...", "....\\n</Check>\\n\\n## What is a **Dashboard**?\\n\\nA **Dashboard** provides a...", "... What is a **Dashboard**?\\n\\nA **Dashboard** provides a clear view of..."], "total_matches": 18}, "filename": "docs/platform/dashboard_overview.mdx"}]'}

# %%
messages.append({"role": "assistant", "content": response.content})
messages.append({"role": "user", "content": [tool_call_result]})

# %%
# 2nd call

response = anthropic_client.messages.create(
    model="claude-haiku-4-5",
    max_tokens=4096,
    system=common.SINGLE_TOOL_SYSTEM_PROMPT,
    messages=messages,
    tools=tools,
)

# %%
response.content
# Out:
# [TextBlock(citations=None, text='Let me get more detailed information about creating dashboards:', type='text'),
#  ToolUseBlock(id='toolu_0168ctyUXgGsoGNqFL4EBYzg', input={'filename': 'docs/platform/dashboard_overview.mdx'}, name='get_file', type='tool_use', caller={'type': 'direct'}),
#  ToolUseBlock(id='toolu_01LAqBEd9kWwazZcxWMfQdNE', input={'filename': 'docs/platform/dashboard_add_panels_ui.mdx'}, name='get_file', type='tool_use', caller={'type': 'direct'})]

# %%
tool_call_results = []

for message in response.content:
    if message.type == 'tool_use':
        print(f'executing {message.name}({message.input})...')
        tool_call_output = make_call(message)
        tool_call_results.append(tool_call_output)

    if message.type == 'text':
        text = message.text
        print('ASSISTANT:', text)
# Out:
# ASSISTANT: Let me get more detailed information about creating dashboards:
# executing get_file({'filename': 'docs/platform/dashboard_overview.mdx'})...
# executing get_file({'filename': 'docs/platform/dashboard_add_panels_ui.mdx'})...

# %%
messages.append({"role": "assistant", "content": response.content})
messages.append({"role": "user", "content": tool_call_results})

# %%
# 3rd call - final

response = anthropic_client.messages.create(
    model="claude-haiku-4-5",
    max_tokens=4096,
    system=common.SINGLE_TOOL_SYSTEM_PROMPT,
    messages=messages,
    tools=tools,
)

# %%
response.content
# Out:
# [TextBlock(citations=None, text='Based on the documentation, here\'s how to create a dashboard in Evidently:\n\n## Basic Steps\n\n1. **Run an Evaluation and Save Reports**: First, you need to run an evaluation and save at least one Report to your Project. The Dashboard is empty until you have Reports with evaluation results.\n\n2. **Access the Dashboard**: Each Project has its own Dashboard that you can populate with Panels.\n\n## Creating Panels (UI Method)\n\nIf you\'re using **Evidently Cloud or Enterprise**, you can create Panels through the user interface:\n\n1. **Enter Edit Mode** - Click the edit button in the top right corner of the Dashboard\n2. **Click "Add Panel"** button\n3. **Configure the Panel** by:\n   - **Selecting a Metric** - Choose which metric to visualize (must match a metric name logged in your Reports)\n   - **Filtering by Tags** (optional) - Use the "From" field to filter data by specific Tags\n   - **Filtering by Metric Label** - For column-level metrics, use the "Where" selector to specify:\n     - Column name\n     - Value type\n   - **Setting a Legend** - Modify what appears in the legend using the "Label" field\n   - **Choosing Panel Type** - Select the visualization type (counter, line plot, bar plot, pie chart, etc.)\n\n4. **Preview and Save** - Review your setup in the preview and click "Save" to add the Panel to your chosen Tab\n\n## Organizing with Tabs\n\n- Add multiple **Tabs** to organize Panels logically\n- Use pre-built Tab templates (like "Columns") for quick setup, or create empty custom Tabs\n- These tabs will populate with data once you have the corresponding Reports\n\n## Using Python API\n\nAlternatively, you can define your Dashboard as code using the Python API (available across all Evidently versions).\n\nFor more details, check the API documentation for [dashboard customization via Python](docs/platform/dashboard_add_panels).', type='text')]

# %%
print(response.content[0].text)
# Out:
# Based on the documentation, here's how to create a dashboard in Evidently:
#
# ## Basic Steps
#
# 1. **Run an Evaluation and Save Reports**: First, you need to run an evaluation and save at least one Report to your Project. The Dashboard is empty until you have Reports with evaluation results.
#
# 2. **Access the Dashboard**: Each Project has its own Dashboard that you can populate with Panels.
#
# ## Creating Panels (UI Method)
#
# If you're using **Evidently Cloud or Enterprise**, you can create Panels through the user interface:
#
# 1. **Enter Edit Mode** - Click the edit button in the top right corner of the Dashboard
# 2. **Click "Add Panel"** button
# 3. **Configure the Panel** by:
#    - **Selecting a Metric** - Choose which metric to visualize (must match a metric name logged in your Reports)
#    - **Filtering by Tags** (optional) - Use the "From" field to filter data by specific Tags
#    - **Filtering by Metric Label** - For column-level metrics, use the "Where" selector to specify:
#      - Column name
#      - Value type
#    - **Setting a Legend** - Modify what appears in the legend using the "Label" field
#    - **Choosing Panel Type** - Select the visualization type (counter, line plot, bar plot, pie chart, etc.)
#
# 4. **Preview and Save** - Review your setup in the preview and click "Save" to add the Panel to your chosen Tab
#
# ## Organizing with Tabs
#
# - Add multiple **Tabs** to organize Panels logically
# - Use pre-built Tab templates (like "Columns") for quick setup, or create empty custom Tabs
# - These tabs will populate with data once you have the corresponding Reports
#
# ## Using Python API
#
# Alternatively, you can define your Dashboard as code using the Python API (available across all Evidently versions).
#
# For more details, check the API documentation for [dashboard customization via Python](docs/platform/dashboard_add_panels).

# %%
message_history = [
    {"role": "user", "content": common.DEFAULT_QUESTION}
]

iteration_number = 1

while True:

    response = anthropic_client.messages.create(
        model="claude-haiku-4-5",
        max_tokens=4096,
        system=common.SINGLE_TOOL_SYSTEM_PROMPT,
        messages=message_history,
        tools=tools,
    )
    
    print(f'iteration number {iteration_number}...')
    message_history.append({"role": "assistant", "content": response.content})

    tool_call_results = []

    for message in response.content:
        if message.type == 'tool_use':
            print(f'executing {message.name}({message.input})...')
            tool_call_output = make_call(message)
            tool_call_results.append(tool_call_output)
    
        if message.type == 'text':
            text = message.text
            print('ASSISTANT:', text)


    if len(tool_call_results) > 0:
        message_history.append({"role": "user", "content": tool_call_results})
    else:
        break

    iteration_number = iteration_number + 1
    print()
# Out:
# iteration number 1...
# executing search({'query': 'create dashboard'})...
#
# iteration number 2...
# ASSISTANT: Let me get more detailed information about creating dashboards:
# executing get_file({'filename': 'docs/platform/dashboard_overview.mdx'})...
# executing get_file({'filename': 'docs/platform/dashboard_add_panels_ui.mdx'})...
#
# iteration number 3...
# ASSISTANT: ## How to Create a Dashboard in Evidently
#
# Here are the key steps to create a dashboard:
#
# ### **1. Prerequisites**
# - Each Project automatically has its own empty Dashboard
# - To populate it, you must first **run an evaluation and save at least one Report** to the Project
#
# ### **2. Add Dashboard Tabs** (Optional)
# - Enter "Edit" mode on the Dashboard (top right corner)
# - Click the plus sign with "add Tab" on the left
# - Choose either:
#   - A **pre-built Tab** template (like "Columns" for text evaluations or column distributions)
#   - An **empty Tab** with a custom name
#
# ### **3. Add Panels**
# To add visualization Panels to your Dashboard:
#
# - Enter "Edit" mode on the Dashboard
# - Click the "Add Panel" button
# - **Configure the Panel** by:
#   - **Select Metrics**: Choose the metric name that matches your logged Reports
#   - **Filter by Tag** (optional): Use the "From" field to filter by specific Tags attached to Reports
#   - **Filter by Metric Label** (optional): Use the "Where" selector to specify additional parameters like:
#     - Column name
#     - Value type
#   - **Set Legend**: Modify what appears in the legend using the "Label" field
#   - **Set Panel Type**: Choose the plot type (counter, line plot, bar plot, pie chart, etc.) and aggregation level (sum, average, last)
# - Use the preview to review your configuration
# - Click "Save" and select which Tab to add the Panel to
#
# ### **4. Create Dashboards as Code**
# Alternatively, you can define your Dashboard using the Python API instead of the UI (see the API documentation for details).
#
# ### **Note**
# - **No-code Dashboard UI** is available in Evidently Cloud and Enterprise only
# - You can add multiple Panels and organize them into different Tabs
# - By clicking on any Panel value, you can drill down into the associated Report and Dataset for further debugging

# %%
from agent_anthropic import AnthropicAgent

# %%
agent = AnthropicAgent(
    llm_client=anthropic_client,
    model="claude-haiku-4-5",
    instructions=common.SINGLE_TOOL_SYSTEM_PROMPT,
    tool_pairs=tool_pairs
)

# %%
messages = agent.loop(common.DEFAULT_QUESTION)
# Out:
# iteration number 1...
# ASSISTANT: I'll search for information on how to create a dashboard in Evidently.
# executing search({'query': 'create dashboard'})...
#
# iteration number 2...
# ASSISTANT: Let me get more detailed information from the dashboard overview and creation guides.
# executing get_file({'filename': 'docs/platform/dashboard_overview.mdx'})...
# executing get_file({'filename': 'docs/platform/dashboard_add_panels_ui.mdx'})...
# executing get_file({'filename': 'docs/platform/dashboard_add_panels.mdx'})...
#
# iteration number 3...
# ASSISTANT: Based on the documentation, here's how to create a dashboard in Evidently:
#
# ## Overview
#
# A **Dashboard** provides a clear view of your AI application performance. Each Project has its own Dashboard, which is empty at first. To populate it, you need to run an evaluation and **save at least one Report** to the Project.
#
# ## Basic Steps
#
# 1. **Create Reports**: First, run evaluations and save at least one Report to your Project. The Dashboard relies on Reports as its data source.
#
# 2. **Add Panels and Tabs**: Once you have Reports, you can add visual elements (Panels) to your Dashboard. You can organize Panels into different Tabs for better organization.
#
# ## Two Ways to Create Dashboards
#
# ### 1. **Using the UI** (Cloud and Enterprise only)
#
# - Enter "Edit" mode on the Dashboard (top right corner)
# - Click "Add Panel" to create a new panel
# - Configure the panel by:
#   - Selecting a **Metric** to plot (must match metric names in your Reports)
#   - Optionally filtering by **Tags** or **Metric labels** (like column name)
#   - Setting the **Panel Type** (counter, line chart, bar chart, pie chart, text, etc.)
#   - Specifying title, subtitle, and size
# - Click "Save" and select which Tab to add the Panel to
#
# ### 2. **Using Python API** (All versions: OSS, Cloud, Enterprise)
#
# ```python
# from evidently.sdk.models import PanelMetric
# from evidently.sdk.panels import DashboardPanelPlot
#
# # Add a tab
# project.dashboard.add_tab("My Tab")
#
# # Add a panel
# project.dashboard.add_panel(
#     DashboardPanelPlot(
#         title="Row count",
#         subtitle="Number of evaluations over time.",
#         size="half",
#         values=[PanelMetric(legend="Row count", metric="RowCount")],
#         plot_params={"plot_type": "line"},
#     ),
#     tab="My Tab",
# )
# ```
#
# ## Key Concepts
#
# - **Panels**: Individual visual widgets (counters, charts, plots) displaying metric values
# - **Metrics**: Individual values extracted from Reports (e.g., `RowCount`, `Accuracy`)
# - **Tabs**: Organize related Panels into logical groups
# - **Tags & Filters**: Filter which Reports' data to include in a Panel
#
# The Panel time resolution depends on your Report frequency—for example, if you log Reports daily, you'll see daily granularity on your Dashboard.
