# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

import common
from search_tools import create_search_tools

evidently_search_tools = create_search_tools()

# %%
import inspect

search_tool = {
    "type": "function",
    "function": {
        "name": evidently_search_tools.search.__name__,
        "description": inspect.getdoc(evidently_search_tools.search),
        "parameters": {
            "type": "object",
            "properties": {
                "query": {
                    "type": "string",
                    "description": "The search query to look up in the index"
                }
            },
            "required": ["query"]
        }
    }
}

get_file_tool = {
    "type": "function",
    "function": {
        "name": evidently_search_tools.get_file.__name__,
        "description": inspect.getdoc(evidently_search_tools.get_file),
        "parameters": {
            "type": "object",
            "properties": {
                "filename": {
                    "type": "string",
                    "description": "The filename to retrieve (e.g., 'docs/setup/installation.mdx')"
                }
            },
            "required": ["filename"]
        }
    }
}

# %%
tool_pairs = [
    (evidently_search_tools.search, search_tool),
    (evidently_search_tools.get_file, get_file_tool)
]

# %%
tools = [t for (_, t) in tool_pairs]
tools_index = {t['function']['name']: f for (f, t) in tool_pairs}

# %%
def make_call(tool_call):
    function = tool_call.function
    name = function.name

    if name in tools_index:
        func = tools_index[name]
        arguments = json.loads(function.arguments)
        result = func(**arguments)
    else:
        result = f"Tool '{name}' not found in tools index"

    return {
        "role": "tool",
        "tool_call_id": tool_call.id,
        "content": json.dumps(result)
    }

# %%
from dataclasses import dataclass

@dataclass
class Function:
    name: str
    arguments: str

@dataclass
class ToolCall:
    id: str
    function: Function
    type: str

tool_call = ToolCall(
    id='call_qKib5siFCJlGHGL2yim6g69l',
    function=Function(
        arguments='{"query":"create a dashboard"}',
        name='search'
    ),
    type='function'
)

tool_call_result = make_call(tool_call)
tool_call_result
# Out:
# {'role': 'tool',
#  'tool_call_id': 'call_qKib5siFCJlGHGL2yim6g69l',
#  'content': '[{"title": "Add dashboard panels (UI)", "description": "How to design your Dashboard with custom Panels.", "content": {"matches": ["**Dashboards** let you **create** Panels to...", "**Dashboards** let you **create** Panels to visualize eval...", "...ject.\\n\\n<Check>\\n  No-code **Dashboards** are available in the Evi..."], "total_matches": 14}, "filename": "docs/platform/dashboard_add_panels_ui.mdx"}, {"title": "Add dashboard panels (API)", "description": "How to design your Dashboard with custom Panels.", "content": {"matches": ["...oard_add_panels_ui).\\n\\n## **Dashboard** Management\\n\\n<Check>\\n  **Dashboards**...", "...rd Management\\n\\n<Check>\\n  **Dashboards** as code are available in...", "...(/docs/setup/cloud) and [**create** a Project](/docs/platfor..."], "total_matches": 32}, "filename": "docs/platform/dashboard_add_panels.mdx"}, {"title": "LLM as a judge", "description": "How to create and evaluate an LLM judge.", "content": {"matches": ["...n demonstrating **how to **create** and tune the LLM evaluat...", "...re\'s what we\'ll do:\\n\\n- ****Create** an evaluation dataset**....", "...an evaluation dataset**. **Create** a toy Q&A dataset.\\n- ****Create**..."], "total_matches": 13}, "filename": "examples/LLM_judge.mdx"}, {"title": "Custom Metric", "description": "How to create a custom dataset or column-level Metric.", "content": {"matches": ["...e a built-in template to **create** a custom [LLM-based eval...", "...sualize over time on the **Dashboard**.\\n\\n## Example implementat...", "... Report as usual.\\n\\nLet\\u2019s **create** a sample toy dataset:\\n\\n`..."], "total_matches": 3}, "filename": "metrics/customize_metric.mdx"}, {"title": "Overview", "description": "Introduction to Dashboard.", "content": {"matches": ["<Check>\\n  **Dashboard** is available in **Eviden...", "....\\n</Check>\\n\\n## What is a **Dashboard**?\\n\\nA **Dashboard** provides a...", "... What is a **Dashboard**?\\n\\nA **Dashboard** provides a clear view of..."], "total_matches": 18}, "filename": "docs/platform/dashboard_overview.mdx"}]'}

# %%
from openai import OpenAI
openai_client = OpenAI()

# %%
messages = [
    {"role": "system", "content": common.SINGLE_TOOL_SYSTEM_PROMPT},
    {"role": "user", "content": common.DEFAULT_QUESTION}
]

# 1st call - initial

response = openai_client.chat.completions.create(
    model='gpt-4o-mini',
    messages=messages,
    tools=tools,
)

# %%
message = response.choices[0].message
message.tool_calls
# Out:
# [ChatCompletionMessageFunctionToolCall(id='call_Js8aRhzHUdLFM9L49Aq77pmb', function=Function(arguments='{"query":"create dashboard"}', name='search'), type='function')]

# %%
tool_call = message.tool_calls[0]
tool_call
# Out:
# ChatCompletionMessageFunctionToolCall(id='call_Js8aRhzHUdLFM9L49Aq77pmb', function=Function(arguments='{"query":"create dashboard"}', name='search'), type='function')

# %%
tool_call_result = make_call(tool_call)

# %%
messages.append(message)
messages.append(tool_call_result)

# %%
# 2nd call

response = openai_client.chat.completions.create(
    model='gpt-4o-mini',
    messages=messages,
    tools=tools,
)

# %%
message = response.choices[0].message
message
# Out:
# ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_zMzrfMFKZBQD3XqAIqdmT7cM', function=Function(arguments='{"filename": "docs/platform/dashboard_overview.mdx"}', name='get_file'), type='function'), ChatCompletionMessageFunctionToolCall(id='call_r7kESvicoGVA7qOZfn1APjlb', function=Function(arguments='{"filename": "docs/platform/dashboard_add_panels_ui.mdx"}', name='get_file'), type='function'), ChatCompletionMessageFunctionToolCall(id='call_NLD9FvBJoVC6faneHlHMizql', function=Function(arguments='{"filename": "docs/platform/dashboard_add_panels.mdx"}', name='get_file'), type='function')])

# %%
messages.append(message)

# %%
message.tool_calls
# Out:
# [ChatCompletionMessageFunctionToolCall(id='call_zMzrfMFKZBQD3XqAIqdmT7cM', function=Function(arguments='{"filename": "docs/platform/dashboard_overview.mdx"}', name='get_file'), type='function'),
#  ChatCompletionMessageFunctionToolCall(id='call_r7kESvicoGVA7qOZfn1APjlb', function=Function(arguments='{"filename": "docs/platform/dashboard_add_panels_ui.mdx"}', name='get_file'), type='function'),
#  ChatCompletionMessageFunctionToolCall(id='call_NLD9FvBJoVC6faneHlHMizql', function=Function(arguments='{"filename": "docs/platform/dashboard_add_panels.mdx"}', name='get_file'), type='function')]

# %%
if message.content:
    print('ASSISTANT:', message.content)

has_function_calls = (message.tool_calls is not None) and \
    (len(message.tool_calls) > 0)

if has_function_calls:
    for tool_call in message.tool_calls:
        function = tool_call.function
        print(f'executing {function.name}({function.arguments})...')
        tool_call_output = make_call(tool_call)
        messages.append(tool_call_output)
# Out:
# executing get_file({"filename": "docs/platform/dashboard_overview.mdx"})...
# executing get_file({"filename": "docs/platform/dashboard_add_panels_ui.mdx"})...
# executing get_file({"filename": "docs/platform/dashboard_add_panels.mdx"})...

# %%
# 3rd call - final

response = openai_client.chat.completions.create(
    model='gpt-4o-mini',
    messages=messages,
    tools=tools,
)

# %%
message = response.choices[0].message

# %%
print(message.content)
# Out:
# To create a dashboard in Evidently, you can follow these steps:
#
# 1. **Understanding the Dashboard**: A Dashboard provides a clear view of your AI application's performance, allowing you to track evaluation results and live production quality over time. Every project has its own Dashboard which is initially empty until you run evaluations and save reports.
#
# 2. **Creating a Dashboard**:
#    - You can add panels to your Dashboard using either the user interface (available in Cloud and Enterprise versions) or through the Python API.
#    - To get started, make sure to run an evaluation and save at least one report to your project, as the Dashboard relies on these reports for visualization.
#
# 3. **Adding Tabs and Panels**:
#    - You can organize your panels into multiple tabs. To add a new tab:
#      1. Enter "Edit" mode on the Dashboard.
#      2. Click the plus sign to add a Tab and enter a name.
#    - To add panels:
#      1. In "Edit" mode, click on "Add Panel."
#      2. Configure the panel by selecting metrics to display, choosing panel types (like counters, plots, etc.), and defining their appearance and content.
#
# 4. **Panel Configuration**:
#    - Specify the values by choosing individual metrics, and you can filter them using tags if necessary.
#    - Set the panel type, size, and any optional parameters such as legends or specific metric labels.
#
# 5. **Example Code for Adding a Panel via API**:
#    Here is a basic example of how you can add a panel programmatically:
#    ```python
#    project.dashboard.add_panel(
#        DashboardPanelPlot(
#            title="Row count",
#            size="half",
#            values=[PanelMetric(legend="Row count", metric="RowCount")],
#            plot_params={"plot_type": "line"},
#        ),
#        tab="My tab",
#    )
#    ```
#
# 6. **Deleting or Editing Panels**:
#    - To delete or edit a panel, enter "Edit" mode and hover over the specific panel to choose the action.
#
# For more detailed instructions on creating dashboards and adding panels, you can refer to the documentation on [adding dashboard panels via the UI](docs/platform/dashboard_add_panels_ui) and [the API](docs/platform/dashboard_add_panels).

# %%
message_history = [
    {"role": "system", "content": common.SINGLE_TOOL_SYSTEM_PROMPT},
    {"role": "user", "content": common.DEFAULT_QUESTION}
]

iteration_number = 1

while True:
    response = openai_client.chat.completions.create(
        model='gpt-4o-mini',
        messages=message_history,
        tools=tools,
    )

    print(f'iteration number {iteration_number}...')
    message = response.choices[0].message
    message_history.append(message)

    if message.content:
        print('ASSISTANT:', message.content)
    
    has_function_calls = (message.tool_calls is not None) and \
        (len(message.tool_calls) > 0)
    
    if has_function_calls:
        for tool_call in message.tool_calls:
            function = tool_call.function
            print(f'executing {function.name}({function.arguments})...')
            tool_call_output = make_call(tool_call)
            message_history.append(tool_call_output)

    if not has_function_calls:
        break

    iteration_number = iteration_number + 1
    print()
# Out:
# iteration number 1...
# executing search({"query":"create a dashboard"})...
#
# iteration number 2...
# executing get_file({"filename": "docs/platform/dashboard_add_panels_ui.mdx"})...
# executing get_file({"filename": "docs/platform/dashboard_add_panels.mdx"})...
# executing get_file({"filename": "docs/platform/dashboard_overview.mdx"})...
#
# iteration number 3...
# ASSISTANT: To create a dashboard, you can use either the user interface or the Python API. Here’s a brief overview of both methods:
#
# ### Using the User Interface
# 1. **Access Dashboard**: Go to the dashboard section in your project.
# 2. **Add Tabs**:
#    - Enter "Edit" mode on the Dashboard.
#    - Click the plus sign that says "Add Tab" on the left.
#    - Optionally, create a custom Tab or select from pre-built Tabs.
# 3. **Add Panels**:
#    - While in "Edit" mode, click on the "Add Panel" button.
#    - Configure the panel by selecting the metric, filtering by tag or metric label if necessary.
#    - Set the panel type (e.g., pie chart, line plot) and other parameters.
#    - Click "Save" and choose the Tab to which you want to add the Panel.
#
# **Note**: Dashboards require that you first save at least one Report to the Project, which will provide the necessary data source for the Panels.
#
# ### Using the Python API
# To manage the dashboard programmatically, you can define your dashboard in code. Here are some common actions:
#
# - **Adding Tabs**:
#   ```python
#   project.dashboard.add_tab("My New Tab")
#   ```
#
# - **Adding Panels**:
#   ```python
#   from evidently.sdk.models import PanelMetric
#   from evidently.sdk.panels import DashboardPanelPlot
#
#   project.dashboard.add_panel(
#       DashboardPanelPlot(
#           title="My Panel Title",
#           size="full",
#           values=[PanelMetric(legend="Metric Legend", metric="MetricName")],
#           plot_params={"plot_type": "line"},
#       ),
#       tab="My New Tab"  # This Tab will be created if it doesn't exist.
#   )
#   ```
#
# - **Deleting Tabs and Panels**:
#   ```python
#   project.dashboard.delete_tab("My New Tab")
#   project.dashboard.delete_panel("My Panel Title", "My Tab")
#   ```
#
# ### Important Notes
# - Ensure you have reports with evaluation results in your project to populate the panels.
# - Each Dashboard can be organized with multiple Tabs, and you can add various types of Panels (text, counters, plots) to visualize the data effectively.
#
# For more detailed instructions and examples, refer to the specific documentation sections on adding dashboard panels through the UI and API.

# %%
from agent_chat_completions import OpenAIChatCompletionsAgent

# %%
agent = OpenAIChatCompletionsAgent(
    llm_client=OpenAI(),
    model='gpt-4o-mini',
    instructions=common.SINGLE_TOOL_SYSTEM_PROMPT,
    tool_pairs=tool_pairs
)

# %%
messages = agent.loop(common.DEFAULT_QUESTION)
# Out:
# iteration number 1...
# executing search({"query":"create a dashboard"})...
#
# iteration number 2...
# executing get_file({"filename": "docs/platform/dashboard_overview.mdx"})...
# executing get_file({"filename": "docs/platform/dashboard_add_panels_ui.mdx"})...
# executing get_file({"filename": "docs/platform/dashboard_add_panels.mdx"})...
#
# iteration number 3...
# ASSISTANT: To create a dashboard, you have two main approaches: using the user interface (UI) or the Python API. Here are the steps for both methods:
#
# ### Using the User Interface (UI)
# 1. **Access the Dashboard**: Each Project has its own Dashboard, which starts empty.
# 2. **Run an Evaluation**: Before you can populate the Dashboard with data, you need to run an evaluation and save at least one Report within the Project.
# 3. **Add Tabs (Optional)**:
#    - Enter "Edit" mode on the Dashboard by clicking the mode switch in the top right corner.
#    - Click the plus sign to add a new Tab; you can create a blank Tab or select from pre-built templates.
#
# 4. **Add Panels**: To add visual elements (Panels) to the Dashboard:
#    - After entering "Edit" mode, click "Add Panel."
#    - Follow the configuration prompts to set up the Panel. You will need to:
#      - Select the Metric you want to display.
#      - Choose the type of Panel (e.g., line plot, bar plot, counter).
#      - Optionally filter by Tags and specify other parameters.
#    - Once configured, click "Save" and select the Tab where you want to add the Panel.
#
# ### Using Python API
# 1. **Connect to Evidently Cloud and Create a Project**: Ensure you have access to the Evidently Cloud and have created a Project.
# 2. **Adding Tabs**:
#    ```python
#    project.dashboard.add_tab("Another Tab")
#    ```
#
# 3. **Adding Panels**: You can add Panels to the Dashboard programmatically. Here’s a basic example:
#    ```python
#    from evidently.sdk.models import PanelMetric
#    from evidently.sdk.panels import DashboardPanelPlot
#
#    project.dashboard.add_panel(
#        DashboardPanelPlot(
#            title="Row Count",
#            values=[PanelMetric(legend="Row Count", metric="RowCount")],
#            plot_params={"plot_type": "line"},
#        ),
#        tab="My Tab"
#    )
#    ```
#
# 4. **Deleting or Editing**: You can also delete or edit existing Tabs and Panels using similar commands in your code.
#
# ### Notes:
# - Dashboards in the UI require no coding skills, while the Python API allows for more customization and programmability.
# - You can view Reports associated with each value on the Dashboard for deeper analysis.
# - Ensure all necessary Reports are created and saved in your Project before adding Panels to visualize their data.
#
# For more detailed instructions, you can refer to the full documentation on adding panels in the UI and using the API.
