# %%
from openai import OpenAI

openai_client = OpenAI()

# %%
response = openai_client.responses.create(
    model="gpt-4o-mini",
    input="tell me a joke about Alexey"
)

# %%
print(response.output_text)
# Out:
# Why did Alexey bring a ladder to the bar?
#
# Because he heard the drinks were on the house!

# %%
messages = [
    {"role": "user", "content": "tell me a joke about Alexey"}
]

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages
)

# %%
print(response.output_text)
# Out:
# Why did Alexey bring a ladder to the bar?
#
# Because he heard the drinks were on the house!

# %%
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "resp_098756a50ad3551f0069777187755481a29b698fdd3bcce79d",
#   "created_at": 1769435527.0,
#   "error": null,
#   "incomplete_details": null,
#   "instructions": null,
#   "metadata": {},
#   "model": "gpt-4o-mini-2024-07-18",
#   "object": "response",
#   "output": [
#     {
#       "id": "msg_098756a50ad3551f00697771882d9c81a29ea0daa2d0036f51",
#       "content": [
#         {
#           "annotations": [],
#           "text": "Why did Alexey bring a ladder to the bar?\n\nBecause he heard the drinks were on the house!",
#           "type": "output_text",
#           "logprobs": []
#         }
#       ],
#       "role": "assistant",
#       "status": "completed",
#       "type": "message"
#     }
#   ],
#   "parallel_tool_calls": true,
#   "temperature": 1.0,
#   "tool_choice": "auto",
#   "tools": [],
#   "top_p": 1.0,
#   "background": false,
#   "completed_at": 1769435528.0,
#   "conversation": null,
#   "max_output_tokens": null,
#   "max_tool_calls": null,
#   "previous_response_id": null,
#   "prompt": null,
#   "prompt_cache_key": null,
#   "prompt_cache_retention": null,
#   "reasoning": {
#     "effort": null,
#     "generate_summary": null,
#     "summary": null
#   },
#   "safety_identifier": null,
#   "service_tier": "default",
#   "status": "completed",
#   "text": {
#     "format": {
#       "type": "text"
#     },
#     "verbosity": "medium"
#   },
#   "top_logprobs": 0,
#   "truncation": "disabled",
#   "usage": {
#     "input_tokens": 14,
#     "input_tokens_details": {
#       "cached_tokens": 0
#     },
#     "output_tokens": 22,
#     "output_tokens_details": {
#       "reasoning_tokens": 0
#     },
#     "total_tokens": 36
#   },
#   "user": null,
#   "billing": {
#     "payer": "openai"
#   },
#   "frequency_penalty": 0.0,
#   "presence_penalty": 0.0,
#   "store": true
# }

# %%
messages = [
    {"role": "user", "content": "tell me a bad time story about a unicorn"}
]

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages
)

# %%
response.usage
# Out:
# ResponseUsage(input_tokens=16, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=475, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=491)

# %%
MODEL_PRICES = {
    "gpt-4o-mini": {"input": 0.15, "output": 0.60},
    "gpt-5-nano": {"input": 0.075, "output": 0.30},
    "gpt-5-mini": {"input": 0.25, "output": 2.00},
    "gpt-5.2": {"input": 1.75, "output": 14.00},
    "gpt-5.2-pro": {"input": 21.00, "output": 168.00},
}

# %%
def calculate_cost(model_name: str, input_tokens: int, output_tokens: int) -> float:
    prices = MODEL_PRICES[model_name.lower()]
    input_cost = (input_tokens / 1_000_000) * prices["input"]
    output_cost = (output_tokens / 1_000_000) * prices["output"]
    return input_cost + output_cost

# %%
usage = response.usage

cost = calculate_cost(
    model_name="gpt-4o-mini",
    input_tokens=usage.input_tokens,
    output_tokens=usage.output_tokens
)

print(f"Cost: ${cost:.6f}")
# Out:
# Cost: $0.000287

# %%
print(response.output_text)
# Out:
# Once upon a time, in a gloomy land far away, there lived a unicorn named Ulysses. Unlike the majestic creatures of legends, Ulysses had a dull gray coat and a twisted horn. While others shimmered with vibrant colors, Ulysses felt like the outcast of the unicorn kingdom.
#
# Every day, he watched his friends soar through the skies, spreading rainbows and laughter. But whenever he tried to join them, they would snicker and say, "Stay back, Ulysses! You'll ruin the fun!" Heartbroken, he often wandered off to the dark corners of the forest, where shadows danced and silence reigned.
#
# One fateful day, Ulysses stumbled upon a dark cave. Intrigued despite himself, he entered, thinking perhaps he could find treasure or a hidden wonder. Inside, the air was thick and damp, and eerie echoes filled the cavern. He ventured deeper until he found a hidden chamber filled with crystals that glowed a sinister red.
#
# Suddenly, he heard a voice. "Welcome, Ulysses. You’ve come seeking power, haven’t you?" A shadowy figure emerged, a wicked sorceress adorned with cursed jewels. Tempted by her offer to become the most beautiful unicorn of all, Ulysses hesitated. He knew that beauty came with a price, but his heart longed for acceptance.
#
# Ignoring his instincts, he agreed. The sorceress waved her hand, and in an instant, Ulysses was transformed into a dazzling unicorn, radiant and enchanting. He raced back to his friends, expecting their awed admiration. Instead, they were terrified, for his new beauty came with a terrible curse: whoever gazed upon him would fall into a deep, endless slumber.
#
# As Ulysses pranced around, his friends began to drift away peacefully, one by one, trapped in their dreams forever. Alone and consumed by guilt, Ulysses had achieved what he longed for, but at a terrible cost. The laughter turned to silence, and the once vibrant kingdom became a desolate realm.
#
# Realizing too late that true beauty lies not in appearances but in kindness and friendship, Ulysses wandered through the empty land, longing for the days filled with laughter. In search of redemption, he returned to the cave, hoping to reverse the curse. But the sorceress only laughed, reminding him that some choices can never be undone.
#
# From that day on, Ulysses roamed the haunted forest, a once-beautiful unicorn now shrouded in darkness, forever in search of the friendships he had lost—constantly reminded that sometimes, wanting to fit in can lead to dire consequences. And so, the tale of Ulysses serves as a cautionary reminder: true beauty comes from within, and the price of vanity can cost you everything.

# %%
stream = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages,
    stream=True
)

response = None
for event in stream:
    events.append(event)
    if hasattr(event, 'delta'):
        print(event.delta, end='')
    if hasattr(event, 'response'):
        response = event.response
# Out:
# Once upon a time in a land not so far away, there lived a unicorn named Sparklehorn. Unlike most unicorns, Sparklehorn had a knack for finding trouble. One sunny day, he decided it would be fun to visit the Rainbow River, known for its shimmering waters and colorful fish.
#
# On his way, Sparklehorn spotted a particularly shiny rock. He couldn't resist picking it up. Unfortunately, this was no ordinary rock—it was a cursed stone that turned everything it touched to mud! As he trotted happily along, he accidentally turned flowers, trees, and even the sparkling river into gooey sludge.
#
# Panicked, Sparklehorn tried to reverse the curse by stomping his hooves, believing that a little unicorn magic would save the day. But instead of fixing the mess, he slipped in the mud and fell flat on his face. To make matters worse, his glittery horn got stuck in a puddle of muck.
#
# Desperate to free himself, Sparklehorn called for help. The other woodland creatures tried to pull him out, but they only got stuck too! The once-beautiful forest was now a muddy disaster zone, filled with trapped animals and sad, drab landscape.
#
# Finally, the wise old owl flew down and offered a solution. “You must return the rock to the Cave of Lost Things, where you found it. Only then will the curse be broken.” With great effort, Sparklehorn freed himself and, with the help of his new friends, trudged back to the cave.
#
# After what felt like an eternity, he returned the rock to its rightful place. Suddenly, a brilliant light flooded the cave, and the curse was lifted! The forest returned to its vibrant self, and the Rainbow River sparkled once more.
#
# But instead of feeling relieved, Sparklehorn was left covered in mud and feeling very sorry for his mischief. From that day on, he learned that curiosity could lead to trouble, and sometimes, even a magical unicorn could have a bad time. And though the forest flourished again, Sparklehorn was forever known as the unicorn who turned the land to mud.
#
# And so, he never played with shiny rocks again. The end.

# %%
response.usage
# Out:
# ResponseUsage(input_tokens=16, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=448, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=464)

# %%
instructions = "make sure to add emojis"
user_prompt = "tell me a bad time story about a unicorn"

messages = [
    {"role": "system", "content": instructions},
    {"role": "user", "content": user_prompt},
]

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages
)

# %%
print(response.output_text)
# Out:
# Once upon a time in a land called Misty Meadows, there lived a unicorn named Glitterhorn. 🌈✨ Unlike other unicorns, Glitterhorn was a bit clumsy and had a knack for getting into trouble.
#
# One sunny morning, Glitterhorn decided to impress her friends by showing off her magical horn. 🌞🦄 As she galloped through the meadows, she spotted a shimmering pond and thought, "I’ll make the water sparkle for everyone!"
#
# With a twirl and a flick of her horn, she focused all her magic. But instead of sparkling water, she accidentally turned the pond into a giant bubble! 🎈 The bubble grew and grew until it popped, covering Glitterhorn in sticky goo. Her friends burst into laughter, and Glitterhorn felt embarrassed.
#
# Determined to redeem herself, Glitterhorn trotted over to a nearby hill to try again. This time, she wanted to make a beautiful rainbow. 🌈 She concentrated hard, but instead of a rainbow, she created a storm cloud! 🌩️ The cloud rumbled and spat out rain, drenching everyone in the meadows.
#
# Feeling miserable and sticky, Glitterhorn hung her head low. Just then, a wise old owl perched on a tree said, "Don't worry, Glitterhorn. Everyone has off days. 🌙✨ What matters is that you keep trying!"
#
# Taking the owl's advice to heart, Glitterhorn decided to embrace her mistakes. She organized a "Bubble and Storm Party," inviting all her friends to join in the fun. 🥳 They laughed, danced in the bubbles, and even played in the rain!
#
# While Glitterhorn may not have had the perfect magical day, she learned that sometimes the best memories come from the unexpected. From then on, she embraced her quirks and grew even closer to her friends. 💖🦄
#
# And so, Glitterhorn’s bad day turned into the best day ever, reminding everyone that everyone has their ups and downs. 🌈💫
#
# The end! 🌟

# %%
instructions = "make sure to add emojis"
user_prompt = "my name is Alexey"

messages = [
    {"role": "system", "content": instructions},
    {"role": "user", "content": user_prompt},
]

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages
)

print(response.output_text)
# Out:
# Nice to meet you, Alexey! 😊 What can I help you with today?

# %%
response = openai_client.responses.create(
    model='gpt-4o-mini',
    input="What's my name?"
)

print(response.output_text)
# Out:
# I don't have access to personal data about you unless you've shared it in this chat. If you'd like to share your name or any other information, feel free!

# %%
instructions = "make sure to add emojis"
user_prompt = "my name is Alexey"

messages = [
    {"role": "system", "content": instructions},
    {"role": "user", "content": user_prompt},
]

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages
)

print(response.output_text)
# Out:
# Nice to meet you, Alexey! 😄 How can I assist you today?

# %%
messages.extend(response.output)

# %%
messages
# Out:
# [{'role': 'system', 'content': 'make sure to add emojis'},
#  {'role': 'user', 'content': 'my name is Alexey'},
#  ResponseOutputMessage(id='msg_003b90a008d9f4a1006977756ef72881a19eb30fbe79c0d522', content=[ResponseOutputText(annotations=[], text='Nice to meet you, Alexey! 😄 How can I assist you today?', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')]

# %%
messages.append(
    {"role": "user", "content": "what's my name?"}
)

# %%
messages
# Out:
# [{'role': 'system', 'content': 'make sure to add emojis'},
#  {'role': 'user', 'content': 'my name is Alexey'},
#  ResponseOutputMessage(id='msg_003b90a008d9f4a1006977756ef72881a19eb30fbe79c0d522', content=[ResponseOutputText(annotations=[], text='Nice to meet you, Alexey! 😄 How can I assist you today?', type='output_text', logprobs=[])], role='assistant', status='completed', type='message'),
#  {'role': 'user', 'content': "what's my name?"}]

# %%
response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages
)

print(response.output_text)
# Out:
# Your name is Alexey! 😊
