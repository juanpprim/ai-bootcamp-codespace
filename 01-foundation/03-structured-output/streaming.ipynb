# %%
from openai import OpenAI

openai_client = OpenAI()

# %%
messages = [
    {"role": "user", "content": "tell me a bad time story about a unicorn"}
]

stream = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages,
    stream=True
)

response = None
for event in stream:
    if hasattr(event, 'delta'):
        print(event.delta, end='')
    if hasattr(event, 'response'):
        response = event.response
# Out:
# Once upon a time in a land not so far away, there was a unicorn named Nimbus. Nimbus was not your typical majestic creature; instead of a shimmering coat and a sparkling horn, his fur was a dull gray, and his horn was crooked. While other unicorns danced in meadows and spread joy, Nimbus often felt left out.
#
# One day, Nimbus decided to go on an adventure to find the legendary Rainbow Falls, a place said to grant wishes. He hoped that maybe, just maybe, it could transform him into the unicorn he always dreamed of being. So, with determination in his heart and a sad little hope in his eyes, he set off.
#
# As he traveled, Nimbus encountered various obstacles. He stumbled over rocks that other unicorns would have gracefully danced around. He got caught in thorn bushes when trying to take shortcuts. Each misstep seemed to reinforce the idea that he would never belong.
#
# After a long and exhausting journey filled with mishaps, Nimbus finally found the Rainbow Falls. The water sparkled with colors like he had never seen. Eagerly, he made a wish to be beautiful and graceful like the others. As he closed his eyes and imagined his transformation, he heard a voice.
#
# "Beauty is in the eye of the beholder," the voice said. Nimbus opened his eyes to see a wise old owl perched nearby. "What you seek lies not in your appearance but within your heart."
#
# Confused and a little disappointed, Nimbus thanked the owl and decided to drink from the falls anyway. But instead of magic, he felt only the cool water touch his lips and trickle down. Feeling disheartened, he turned to leave.
#
# As he walked back toward home, he noticed something unusual: every time he stumbled, creatures of the forest rushed to help him. He realized that while he may not have fit the mold of the perfect unicorn, he had something else—kindness. The more he helped others with their problems, the more comfortable he felt with himself.
#
# Finally home, Nimbus reflected on his journey. He would never be like the other unicorns, but he had learned that true greatness lies in being true to oneself. A few days later, while helping a lost rabbit find its way, Nimbus discovered the real magic in his heart: friendship and kindness.
#
# And even if Nimbus never looked like a typical unicorn, he learned that being a one-of-a-kind friend was much more important.
#
# So, the next time you see a unicorn, remember that it’s not all about the sparkles and grace—sometimes, it’s about the heart. And though Nimbus didn’t get his wish, he found something better.
#
# The end.

# %%
from pydantic import BaseModel, Field

# %%
class ArticleSection(BaseModel):
    header: str
    text: str = Field(description="text of the section in markdown")

class ArticleResponse(BaseModel):
    title: str
    subtitle: str
    sections: list[ArticleSection]

# %%
messages = [
    {"role": "user", "content": "tell me a bad time story about a unicorn"}
]

with openai_client.responses.stream(
    model="gpt-4o-mini",
    input=messages,
    text_format=ArticleResponse,
) as stream:
    response = None
    for event in stream:
        if hasattr(event, 'delta'):
            print(event.delta, end='')
        if hasattr(event, 'response'):
            response = event.response
# Out:
# {"title":"The Misadventures of Sparkle, the Unicorn","subtitle":"A Tale of Trouble and Lessons","sections":[{"header":"Once Upon a Time","text":"In a magical land far, far away, there lived a young unicorn named Sparkle. She was known for her shimmering coat and dazzling horn, but she had one major flaw: a mischievous streak that often led to chaos."},{"header":"The Forbidden Forest","text":"One sunny morning, Sparkle overheard her friends talking about the Forbidden Forest, a place where no unicorn dared to go. They said it was filled with danger and dark magic. But Sparkle, intrigued by the thrill, decided to venture into the forest alone."},{"header":"A Wretched Encounter","text":"As she galloped deeper into the forest, Sparkle found herself surrounded by eerie shadows and ominous sounds. Suddenly, she stumbled upon a group of grumpy trolls who were not too happy to see an intruder. Instead of being scared, Sparkle decided to play a prank on them."},{"header":"The Troll Trap","text":"Using her magic, she conjured up illusions of beautiful flowers and sparkling jewels. The trolls, greedy and foolish, fell for her trick and rushed toward the illusions. However, in doing so, they knocked over a giant boulder, blocking Sparkle's way back."},{"header":"The Consequences","text":"Trapped and surrounded by trolls who were now angrier than ever, Sparkle realized her mischief had backfired. Her only hope was to escape the trolls and unblock the path, but her magic was drained from the prank."},{"header":"A Lesson Learned","text":"Just when things seemed bleak, Sparkle remembered her true friends who would come looking for her. She calmed herself, using her wit instead of magic. She negotiated with the trolls to let her go, promising never to trespass again."},{"header":"Home Safe, but Changed","text":"With the trolls distracted by a fine tale of treasures far beyond the forest, Sparkle dashed away and eventually found her way home. Though she escaped, she learned that her mischievous nature could lead her into great trouble. From that day on, Sparkle decided to be a better friend and use her magic wisely."},{"header":"The End","text":"And so, the tale of Sparkle the unicorn spread throughout the land, reminding everyone that sometimes, the thrill of adventure can come with consequences. And being true to oneself is the most magical lesson of all."}]}

# %%
story = response.output_parsed

# %%
print('# ' + story.title)
print(story.subtitle)
print()

for section in story.sections:
    print('## ' + section.header)
    print()
    print(section.text)
    print()
    print()
# Out:
# # The Misadventures of Sparkle, the Unicorn
# A Tale of Trouble and Lessons
#
# ## Once Upon a Time
#
# In a magical land far, far away, there lived a young unicorn named Sparkle. She was known for her shimmering coat and dazzling horn, but she had one major flaw: a mischievous streak that often led to chaos.
#
#
# ## The Forbidden Forest
#
# One sunny morning, Sparkle overheard her friends talking about the Forbidden Forest, a place where no unicorn dared to go. They said it was filled with danger and dark magic. But Sparkle, intrigued by the thrill, decided to venture into the forest alone.
#
#
# ## A Wretched Encounter
#
# As she galloped deeper into the forest, Sparkle found herself surrounded by eerie shadows and ominous sounds. Suddenly, she stumbled upon a group of grumpy trolls who were not too happy to see an intruder. Instead of being scared, Sparkle decided to play a prank on them.
#
#
# ## The Troll Trap
#
# Using her magic, she conjured up illusions of beautiful flowers and sparkling jewels. The trolls, greedy and foolish, fell for her trick and rushed toward the illusions. However, in doing so, they knocked over a giant boulder, blocking Sparkle's way back.
#
#
# ## The Consequences
#
# Trapped and surrounded by trolls who were now angrier than ever, Sparkle realized her mischief had backfired. Her only hope was to escape the trolls and unblock the path, but her magic was drained from the prank.
#
#
# ## A Lesson Learned
#
# Just when things seemed bleak, Sparkle remembered her true friends who would come looking for her. She calmed herself, using her wit instead of magic. She negotiated with the trolls to let her go, promising never to trespass again.
#
#
# ## Home Safe, but Changed
#
# With the trolls distracted by a fine tale of treasures far beyond the forest, Sparkle dashed away and eventually found her way home. Though she escaped, she learned that her mischievous nature could lead her into great trouble. From that day on, Sparkle decided to be a better friend and use her magic wisely.
#
#
# ## The End
#
# And so, the tale of Sparkle the unicorn spread throughout the land, reminding everyone that sometimes, the thrill of adventure can come with consequences. And being true to oneself is the most magical lesson of all.

# %% [markdown]
# !uv add --editable C:/Users/alexe/git/jaxn

# %%
# !uv add jaxn
# Out:
# Resolved 121 packages in 1.35s
# Prepared 1 package in 117ms
# Uninstalled 1 package in 9ms
# Installed 1 package in 30ms
#  - jaxn==0.0.3
#  + jaxn==0.0.4

# %%
from jaxn import JSONParserHandler, StreamingJSONParser

# %%
raw_json = """
{"title":"The Misadventures of Sparkle, the Unicorn","subtitle":"A Tale of Trouble and Lessons","sections":[{"header":"Once Upon a Time","text":"In a magical land far, far away, there lived a young unicorn named Sparkle. She was known for her shimmering coat and dazzling horn, but she had one major flaw: a mischievous streak that often led to chaos."},{"header":"The Forbidden Forest","text":"One sunny morning, Sparkle overheard her friends talking about the Forbidden Forest, a place where no unicorn dared to go. They said it was filled with danger and dark magic. But Sparkle, intrigued by the thrill, decided to venture into the forest alone."},{"header":"A Wretched Encounter","text":"As she galloped deeper into the forest, Sparkle found herself surrounded by eerie shadows and ominous sounds. Suddenly, she stumbled upon a group of grumpy trolls who were not too happy to see an intruder. Instead of being scared, Sparkle decided to play a prank on them."},{"header":"The Troll Trap","text":"Using her magic, she conjured up illusions of beautiful flowers and sparkling jewels. The trolls, greedy and foolish, fell for her trick and rushed toward the illusions. However, in doing so, they knocked over a giant boulder, blocking Sparkle's way back."},{"header":"The Consequences","text":"Trapped and surrounded by trolls who were now angrier than ever, Sparkle realized her mischief had backfired. Her only hope was to escape the trolls and unblock the path, but her magic was drained from the prank."},{"header":"A Lesson Learned","text":"Just when things seemed bleak, Sparkle remembered her true friends who would come looking for her. She calmed herself, using her wit instead of magic. She negotiated with the trolls to let her go, promising never to trespass again."},{"header":"Home Safe, but Changed","text":"With the trolls distracted by a fine tale of treasures far beyond the forest, Sparkle dashed away and eventually found her way home. Though she escaped, she learned that her mischievous nature could lead her into great trouble. From that day on, Sparkle decided to be a better friend and use her magic wisely."},{"header":"The End","text":"And so, the tale of Sparkle the unicorn spread throughout the land, reminding everyone that sometimes, the thrill of adventure can come with consequences. And being true to oneself is the most magical lesson of all."}]}
""".strip()

# %%
from typing import Any, Dict

class ArticleResponseHandler(JSONParserHandler):

    def on_field_end(self, path: str, field_name: str, value: str, parsed_value: Any = None) -> None:
        if path == '':
            if field_name == 'title':
                print(f'# {value}')
            if field_name == 'subtitle':
                print(value)
        if path == '/sections' and field_name == 'header':
            print(f'\n\n## {value}\n')

    def on_value_chunk(self, path: str, field_name: str, chunk: str) -> None:
        if path == '/sections' and field_name == 'text':
            print(chunk, end='', flush=True)

# %%
handler = ArticleResponseHandler()
parser = StreamingJSONParser(handler=handler)

# %%
for c in raw_json:
    parser.parse_incremental(c)
# Out:
# # The Misadventures of Sparkle, the Unicorn
# A Tale of Trouble and Lessons
#
#
# ## Once Upon a Time
#
# In a magical land far, far away, there lived a young unicorn named Sparkle. She was known for her shimmering coat and dazzling horn, but she had one major flaw: a mischievous streak that often led to chaos.
#
# ## The Forbidden Forest
#
# One sunny morning, Sparkle overheard her friends talking about the Forbidden Forest, a place where no unicorn dared to go. They said it was filled with danger and dark magic. But Sparkle, intrigued by the thrill, decided to venture into the forest alone.
#
# ## A Wretched Encounter
#
# As she galloped deeper into the forest, Sparkle found herself surrounded by eerie shadows and ominous sounds. Suddenly, she stumbled upon a group of grumpy trolls who were not too happy to see an intruder. Instead of being scared, Sparkle decided to play a prank on them.
#
# ## The Troll Trap
#
# Using her magic, she conjured up illusions of beautiful flowers and sparkling jewels. The trolls, greedy and foolish, fell for her trick and rushed toward the illusions. However, in doing so, they knocked over a giant boulder, blocking Sparkle's way back.
#
# ## The Consequences
#
# Trapped and surrounded by trolls who were now angrier than ever, Sparkle realized her mischief had backfired. Her only hope was to escape the trolls and unblock the path, but her magic was drained from the prank.
#
# ## A Lesson Learned
#
# Just when things seemed bleak, Sparkle remembered her true friends who would come looking for her. She calmed herself, using her wit instead of magic. She negotiated with the trolls to let her go, promising never to trespass again.
#
# ## Home Safe, but Changed
#
# With the trolls distracted by a fine tale of treasures far beyond the forest, Sparkle dashed away and eventually found her way home. Though she escaped, she learned that her mischievous nature could lead her into great trouble. From that day on, Sparkle decided to be a better friend and use her magic wisely.
#
# ## The End
#
# And so, the tale of Sparkle the unicorn spread throughout the land, reminding everyone that sometimes, the thrill of adventure can come with consequences. And being true to oneself is the most magical lesson of all.

# %%
def llm_structured_stream(
        user_prompt,
        output_type,
        parser_handler=JSONParserHandler(),
        instructions=None,
        model="gpt-4o-mini",
    ):
    messages = []

    if instructions:
        messages.append({
            "role": "system",
            "content": instructions
        })

    messages.append({
        "role": "user",
        "content": user_prompt
    })

    parser = StreamingJSONParser(handler=parser_handler)

    with openai_client.responses.stream(
        model="gpt-4o-mini",
        input=messages,
        text_format=output_type,
    ) as stream:
        response = None
        for event in stream:
            if hasattr(event, 'delta'):
                parser.parse_incremental(event.delta)
            if hasattr(event, 'response'):
                response = event.response

    return response

# %%
instructions = "your task is to tell the user bad time stories"
user_prompt =  "unicorn"

result = llm_structured_stream(
    instructions=instructions,
    user_prompt=user_prompt,
    output_type=ArticleResponse,
    parser_handler=ArticleResponseHandler(),
)
# Out:
# # The Sad Tale of the Silenced Unicorn
# A Story of Lost Magic
#
#
# ## Once Upon a Time
#
# In a hidden valley, far away from the chaos of the world, lived a majestic unicorn named Liora. With a shimmering mane that sparkled under the moonlight and a horn that glowed with the colors of a rainbow, she was the last of her kind. But Liora's beauty came with a heavy burden.
#
# ## The Price of Greatness
#
# Unlike others of her kin, Liora had been cursed by a jealous sorceress who feared the magic of unicorns. The curse silenced her voice and stripped her of the ability to heal. No longer could she sing to the forest or bring forth the blooming flowers in spring. The once vibrant valley began to wither and fade, mirroring Liora's own sadness.
#
# ## Searching for Hope
#
# Determined to break the curse, Liora embarked on a quest to find the witch who had cast it upon her. She crossed treacherous mountains, faced fearsome creatures, and even navigated through dark, enchanted forests. But the more she journeyed, the more she realized that her hope was dwindling.
#
# ## The Final Confrontation
#
# After many moons of searching, Liora finally found the sorceress in a hidden cave. With her heart pounding and tears in her eyes, Liora approached the witch, who cackled at her misery. 'You think you can take back your magic?' the witch taunted. Courageously, Liora shook her head, tears flowing down her face as she shone her light in the darkness.
#
# ## A Heavy Decision
#
# In that moment, the sorceress revealed the truth: the only way to regain her voice was to give away her magic forever. Torn between her desire to speak and the love she felt for her valley and its creatures, Liora realized that her true strength lay not in her words, but in her heart.
#
# ## The Cost of Silence
#
# She chose to let go of her magic, breaking the curse. Liora's voice returned, but the glow of her horn faded. The valley began to bloom again, but Liora always felt a void within her. Though she could now sing, each note reminded her of what she had lost.
#
# ## Legacy of the Unicorn
#
# Though Liora lived many more years, she never regained her magical glow. Yet, she spent her days teaching the creatures of the valley about kindness, love, and the importance of selflessness. The valley flourished, filled with life and laughter once more, but the tale of Liora’s sacrifice echoed through generations, a bittersweet reminder of the magic that once was.

# %%
import json

from gitsource import GithubRepositoryDataReader, chunk_documents
from minsearch import Index

reader = GithubRepositoryDataReader(
    repo_owner="evidentlyai",
    repo_name="docs",
    allowed_extensions={"md", "mdx"},
)
files = reader.read()

parsed_docs = [doc.parse() for doc in files]
chunked_docs = chunk_documents(parsed_docs, size=3000, step=1500)

index = Index(
    text_fields=["title", "description", "content"],
    keyword_fields=["filename"]
)
index.fit(chunked_docs)

print(f"Indexed {len(chunked_docs)} chunks from {len(files)} documents")

def search(query):
    results = index.search(
        query=query,
        num_results=5
    )
    return results



instructions = """
You're a documentation assistant. Answer the QUESTION based on the CONTEXT from our documentation.

Use only facts from the CONTEXT when answering.
If the answer isn't in the CONTEXT, say so.
"""


prompt_template = """
<QUESTION>
{question}
</QUESTION>

<CONTEXT>
{context}
</CONTEXT>
""".strip()

def build_prompt(question, search_results):
    context = json.dumps(search_results, indent=2)
    return prompt_template.format(
        question=question,
        context=context
    )
# Out:
# Indexed 385 chunks from 95 documents

# %%
from typing import Literal

class RAGResponse(BaseModel):
    """
    This model provides a structured answer with metadata about the response,
    including confidence, categorization, and follow-up suggestions.
    """

    answer: str = Field(description="The main answer to the user's question in markdown")
    found_answer: bool = Field(description="True if relevant information was found in the documentation")
    confidence: float = Field(description="Confidence score from 0.0 to 1.0 indicating how certain the answer is")
    confidence_explanation: str = Field(description="Explanation about the confidence level")
    answer_type: Literal["how-to", "explanation", "troubleshooting", "comparison", "reference"] = Field(description="The category of the answer")
    followup_questions: list[str] = Field(description="Suggested follow-up questions the user might want to ask")

# %%
class RAGResponseHandler(JSONParserHandler):
    def on_value_chunk(self, path: str, field_name: str, chunk: str) -> None:
        if path == '' and field_name == 'answer':
            print(chunk, end='', flush=True)

    def on_field_end(self, path: str, field_name: str, value: str, parsed_value: Any = None) -> None:
        if path == '' and field_name == 'answer_type':
            print('\nanswer type:', value)

    def on_array_item_end(self, path: str, field_name: str, item: Dict[str, Any] = None) -> None:
        if field_name == 'followup_questions':
            print('follow up question:', item)

# %%
def rag(query):
    search_results = search(query)
    prompt = build_prompt(query, search_results)
    return llm_structured_stream(
        instructions=instructions,
        user_prompt=prompt,
        output_type=RAGResponse,
        parser_handler=RAGResponseHandler()
    )

# %%
response = rag('llm as a judge')
# Out:
# Using an LLM (Large Language Model) as a judge involves creating an evaluator that can assess text based on custom criteria. Here are two primary methods for utilizing an LLM as a judge:
#
# 1. **Reference-based Evaluation**: This approach involves comparing new responses to a set of reference answers (approved responses). It is commonly used for regression testing where there is a predetermined 'ground truth' to evaluate against.
#
# 2. **Open-ended Evaluation**: Here, the LLM evaluates responses based on custom-defined criteria, which is particularly useful when no reference answers are available.
#
# ### Steps to Implement LLM as a Judge
#
# - **Create an Evaluation Dataset**: You'll need a dataset containing questions, target responses, new responses for evaluation, and manual labels indicating the correctness of responses.
# - **Run the LLM Evaluator**: Develop a prompt for the LLM to evaluate the text response. You can set up prompts for different evaluation focuses, such as correctness or verbosity.
# - **Evaluate the LLM Judge**: After the LLM evaluates the responses, you should compare the evaluations against manual labels to assess the quality of the LLM's judgments.
#
# ### Requirements
# - Basic Python knowledge
# - An OpenAI API key to access the LLM evaluator
#
# ### Tools
# - It is recommended to use environments like Jupyter Notebook or Google Colab to visually inspect results.
#
# This tutorial aids in refining the LLM evaluator's effectiveness through iteration, allowing for improved quality in assessment within various contexts.
# answer type: how-to
# follow up question: What are the best practices for tuning the LLM evaluator?
# follow up question: Can the LLM judge be used for multiple types of evaluations?
# follow up question: What are the limitations of using LLM as a judge?
